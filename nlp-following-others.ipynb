# %%
# Install Keras 3 last. 
# See https://keras.io/getting_started/ for more details.
    
# !pip install -q -U keras-nlp datasets
# !pip install -q -U keras

import keras
import keras_nlp
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.4.35 requires ml-dtypes>=0.4.0, but you have ml-dtypes 0.3.2 which is incompatible.

# %%
import os

# Set the backbend before importing Keras
os.environ["KERAS_BACKEND"] = "jax"
# Avoid memory fragmentation on JAX backend.
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = "1.00"

# Training Configurations
token_limit = 256
lora_name = "translator"
lora_rank = 4
lr_value = 1e-4
train_epoch = 5
model_id = "gemma2_instruct_2b_en"

# %%
import time

# time count
tick_start=0

def tick():
    global tick_start
    tick_start= time.time()

def tock():
    print(f"total elapsed time: {time.time() - tick_start:.2f}s")

# %%
## text generation process

def text_gen(prompt):
    tick()

    input= f"[start] user\n{prompt}[end]\n[start] model\n"
    output= gemma.generate(input, max_length=token_limit)
    print("\nGemma Input: ")
    print(output)
    
    tock()

## import gemma models
gemma = keras_nlp.models.GemmaCausalLM.from_preset(model_id)
gemma.summary()
# Out:
# normalizer.cc(51) LOG(INFO) precompiled_charsmap is empty. use identity normalization.
# Preprocessor: "gemma_causal_lm_preprocessor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                                                  ┃                                   Config ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ gemma_tokenizer (GemmaTokenizer)                              │                      Vocab size: 256,000 │
# └───────────────────────────────────────────────────────────────┴──────────────────────────────────────────┘
# Model: "gemma_causal_lm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ padding_mask (InputLayer)     │ (None, None)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ token_ids (InputLayer)        │ (None, None)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gemma_backbone                │ (None, None, 2304)        │   2,614,341,888 │ padding_mask[0][0],        │
# │ (GemmaBackbone)               │                           │                 │ token_ids[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ token_embedding               │ (None, None, 256000)      │     589,824,000 │ gemma_backbone[0][0]       │
# │ (ReversibleEmbedding)         │                           │                 │                            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,614,341,888 (9.74 GB)
#  Trainable params: 2,614,341,888 (9.74 GB)
#  Non-trainable params: 0 (0.00 B)

# %%
text_gen("ᄃᆡ작ᄒᆞ여그ᄭᅩᆺ치흣터지거ᄂᆞᆯ")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733530512.158919      70 service.cc:145] XLA service 0x7c704249c120 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733530512.160168      70 service.cc:153]   StreamExecutor device (0): Host, Default Version
# I0000 00:00:1733530512.653383      67 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Gemma Input:
# [start] user
# ᄃᆡ작ᄒᆞ여그ᄭᅩᆺ치흣터지거ᄂᆞᆯ[end]
# [start] model
# The provided text appears to be a Korean word or phrase.
#
# Here's a breakdown of why and some potential interpretations:
#
# * **Korean Language:** The characters used are a mix of Korean Hangul (한글) and possibly some non-Hangul characters.
# * **Possible Interpretations:**
#     * **Nonsense Word:** It could be a random string of characters with no specific meaning.
#     * **Typo:** There might be a typo in the input, and the intended text is different.
#     * **Code:** It could be a code or cipher, but without context, it's difficult to decipher.
#     * **Korean Phrase:** It's possible that it's a fragment of a longer Korean phrase or sentence.
#
# **To get a more accurate interpretation, please provide more context:**
#
# * **Source:** Where did you find this text?
# * **Purpose:** What is the purpose of the text?
# * **Additional Information:** Are there any other clues or hints that might help decipher it?
#
#
# Let me know
# total elapsed time: 189.32s
